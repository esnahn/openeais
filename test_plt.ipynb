# %%
import matplotlib.pyplot as plt
import auri

# %%
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plotting the data
plt.plot(x, y, marker="o", linestyle="-", label="Sample Plot")

# Adding labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sample Plot가나다")

# Adding a legend
plt.legend()

# Displaying the plot
plt.grid(True)
plt.show()
