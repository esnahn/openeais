# %%
import polars as pl
from pathlib import Path
from pprint import pprint

df_master = pl.scan_parquet("data/건축물대장_기본개요_2022년_12월/*")
df_site = pl.scan_parquet("data/건축물대장_총괄표제부_2022년_12월/*")
df_dong = pl.scan_parquet("data/건축물대장_표제부_2022년_12월/*")
df_floor = pl.scan_parquet("data/건축물대장_층별개요_2022년_12월/*")
df_building_permit_parking = pl.scan_parquet("data/건축인허가_주차장_2022년_12월/*")
df_housing_permit_parking = pl.scan_parquet("data/주택인허가_주차장_2022년_12월/*")

# %%
df_master.columns
# Out:
# ['관리_상위_건축물대장_PK',
#  '대장_구분_코드',
#  '대장_구분_코드_명',
#  '대장_종류_코드',
#  '대장_종류_코드_명',
#  '대지_위치',
#  '도로명_대지_위치',
#  '건물_명',
#  '시군구_코드',
#  '법정동_코드',
#  '대지_구분_코드',
#  '번',
#  '지',
#  '특수지_명',
#  '블록',
#  '로트',
#  '외필지_수',
#  '새주소_도로_코드',
#  '새주소_법정동_코드',
#  '새주소_지상지하_코드',
#  '새주소_본_번',
#  '새주소_부_번',
#  '지역_코드',
#  '지구_코드',
#  '구역_코드',
#  '지역_코드_명',
#  '지구_코드_명',
#  '구역_코드_명',
#  '생성_일자',
#  '관리_건축물대장_PK']

# %%
df_site.columns
# Out:
# ['대장_구분_코드',
#  '대장_구분_코드_명',
#  '대장_종류_코드',
#  '대장_종류_코드_명',
#  '신_구_대장_구분_코드',
#  '신_구_대장_구분_코드_명',
#  '대지_위치',
#  '도로명_대지_위치',
#  '건물_명',
#  '시군구_코드',
#  '법정동_코드',
#  '대지_구분_코드',
#  '번',
#  '지',
#  '특수지_명',
#  '블록',
#  '로트',
#  '외필지_수',
#  '새주소_도로_코드',
#  '새주소_법정동_코드',
#  '새주소_지상지하_코드',
#  '새주소_본_번',
#  '새주소_부_번',
#  '대지_면적(㎡)',
#  '건축_면적(㎡)',
#  '건폐_율(%)',
#  '연면적(㎡)',
#  '용적_률_산정_연면적(㎡)',
#  '용적_률(%)',
#  '주_용도_코드',
#  '주_용도_코드_명',
#  '기타_용도',
#  '세대_수(세대)',
#  '가구_수(가구)',
#  '주_건축물_수',
#  '부속_건축물_수',
#  '부속_건축물_면적(㎡)',
#  '총_주차_수',
#  '옥내_기계식_대수(대)',
#  '옥내_기계식_면적(㎡)',
#  '옥외_기계식_대수(대)',
#  '옥외_기계식_면적(㎡)',
#  '옥내_자주식_대수(대)',
#  '옥내_자주식_면적(㎡)',
#  '옥외_자주식_대수(대)',
#  '옥외_자주식_면적(㎡)',
#  '허가_일',
#  '착공_일',
#  '사용승인_일',
#  '허가번호_년',
#  '허가번호_기관_코드',
#  '허가번호_기관_코드_명',
#  '허가번호_구분_코드',
#  '허가번호_구분_코드_명',
#  '호_수(호)',
#  '에너지효율_등급',
#  '에너지절감_율',
#  '에너지_EPI점수',
#  '친환경_건축물_등급',
#  '친환경_건축물_인증점수',
#  '지능형_건축물_등급',
#  '지능형_건축물_인증점수',
#  '생성_일자',
#  '관리_건축물대장_PK']

# %%
df_dong.columns
# Out:
# ['대장_구분_코드',
#  '대장_구분_코드_명',
#  '대장_종류_코드',
#  '대장_종류_코드_명',
#  '대지_위치',
#  '도로명_대지_위치',
#  '건물_명',
#  '시군구_코드',
#  '법정동_코드',
#  '대지_구분_코드',
#  '번',
#  '지',
#  '특수지_명',
#  '블록',
#  '로트',
#  '외필지_수',
#  '새주소_도로_코드',
#  '새주소_법정동_코드',
#  '새주소_지상지하_코드',
#  '새주소_본_번',
#  '새주소_부_번',
#  '동_명',
#  '주_부속_구분_코드',
#  '주_부속_구분_코드_명',
#  '대지_면적(㎡)',
#  '건축_면적(㎡)',
#  '건폐_율(%)',
#  '연면적(㎡)',
#  '용적_률_산정_연면적(㎡)',
#  '용적_률(%)',
#  '구조_코드',
#  '구조_코드_명',
#  '기타_구조',
#  '주_용도_코드',
#  '주_용도_코드_명',
#  '기타_용도',
#  '지붕_코드',
#  '지붕_코드_명',
#  '기타_지붕',
#  '세대_수(세대)',
#  '가구_수(가구)',
#  '높이(m)',
#  '지상_층_수',
#  '지하_층_수',
#  '승용_승강기_수',
#  '비상용_승강기_수',
#  '부속_건축물_수',
#  '부속_건축물_면적(㎡)',
#  '총_동_연면적(㎡)',
#  '옥내_기계식_대수(대)',
#  '옥내_기계식_면적(㎡)',
#  '옥외_기계식_대수(대)',
#  '옥외_기계식_면적(㎡)',
#  '옥내_자주식_대수(대)',
#  '옥내_자주식_면적(㎡)',
#  '옥외_자주식_대수(대)',
#  '옥외_자주식_면적(㎡)',
#  '허가_일',
#  '착공_일',
#  '사용승인_일',
#  '허가번호_년',
#  '허가번호_기관_코드',
#  '허가번호_기관_코드_명',
#  '허가번호_구분_코드',
#  '허가번호_구분_코드_명',
#  '호_수(호)',
#  '에너지효율_등급',
#  '에너지절감_율',
#  '에너지_EPI점수',
#  '친환경_건축물_등급',
#  '친환경_건축물_인증점수',
#  '지능형_건축물_등급',
#  '지능형_건축물_인증점수',
#  '생성_일자',
#  '내진_설계_적용_여부',
#  '내진_능력',
#  '관리_건축물대장_PK']

# %%
df_building_permit_parking.columns
# Out:
# ['관리_허가대장_PK',
#  '대지_위치',
#  '시군구_코드',
#  '법정동_코드',
#  '대지_구분_코드',
#  '번',
#  '지',
#  '특수지_명',
#  '블록',
#  '로트',
#  '옥내_자주식_대수(대)',
#  '옥내_자주식_면적(㎡)',
#  '옥외_자주식_대수(대)',
#  '옥외_자주식_면적(㎡)',
#  '옥내_기계식_대수(대)',
#  '옥내_기계식_면적(㎡)',
#  '옥외_기계식_대수(대)',
#  '인근_자주식_대수(대)',
#  '면제_대수(대)',
#  '인근_자주식_면적(㎡)',
#  '옥외_기계식_면적(㎡)',
#  '인근_기계식_대수(대)',
#  '인근_기계식_면적(㎡)',
#  '생성_일자',
#  '__null_dask_index__']

# %%
df_housing_permit_parking.schema
# Out:
# {'관리_주택대장_PK': Utf8,
#  '대지_위치': Utf8,
#  '시군구_코드': Utf8,
#  '법정동_코드': Utf8,
#  '대지_구분_코드': Utf8,
#  '번': Utf8,
#  '지': Utf8,
#  '특수지_명': Utf8,
#  '블록': Utf8,
#  '로트': Utf8,
#  '옥내_자주식_대수(대)': Int64,
#  '옥내_자주식_면적(㎡)': Float64,
#  '옥외_자주식_대수(대)': Int64,
#  '옥외_자주식_면적(㎡)': Float64,
#  '옥내_기계식_대수(대)': Int64,
#  '옥내_기계식_면적(㎡)': Float64,
#  '옥외_기계식_대수(대)': Int64,
#  '인근_자주식_대수(대)': Int64,
#  '면제_대수(대)': Int64,
#  '인근_자주식_면적(㎡)': Float64,
#  '옥외_기계식_면적(㎡)': Float64,
#  '인근_기계식_대수(대)': Int64,
#  '인근_기계식_면적(㎡)': Float64,
#  '생성_일자': Utf8,
#  '__null_dask_index__': Int64}

# %%
near50 = pl.col("인근_자주식_대수(대)") >= 50

# %%
df_near_building = (
    df_building_permit_parking.select(
        [
            "관리_허가대장_PK",
            "대지_위치",
            "시군구_코드",
            "법정동_코드",
            "대지_구분_코드",
            "번",
            "지",
            "특수지_명",
            "블록",
            "로트",
            "인근_자주식_대수(대)",
            "인근_자주식_면적(㎡)",
            "생성_일자",
        ]
    )
    .filter(near50)
    .groupby(
        [
            "시군구_코드",
            "법정동_코드",
            "대지_구분_코드",
            "번",
            "지",
        ]
    )
    .agg(
        [
            pl.all().sort_by("생성_일자").last(),
        ]
    )
    .collect()
)
len(df_near_building)
# Out:
# 619

# %%
df_near_building.head()
# Out:
# shape: (5, 13)
# ┌────────────┬────────────┬────────────┬──────┬───┬──────┬────────────┬───────────────┬────────────┐
# │ 시군구_코  ┆ 법정동_코  ┆ 대지_구분_ ┆ 번   ┆ … ┆ 로트 ┆ 인근_자주  ┆ 인근_자주식_  ┆ 생성_일자  │
# │ 드         ┆ 드         ┆ 코드       ┆ ---  ┆   ┆ ---  ┆ 식_대수(대 ┆ 면적(㎡)      ┆ ---        │
# │ ---        ┆ ---        ┆ ---        ┆ str  ┆   ┆ str  ┆ )          ┆ ---           ┆ str        │
# │ str        ┆ str        ┆ str        ┆      ┆   ┆      ┆ ---        ┆ f64           ┆            │
# │            ┆            ┆            ┆      ┆   ┆      ┆ i64        ┆               ┆            │
# ╞════════════╪════════════╪════════════╪══════╪═══╪══════╪════════════╪═══════════════╪════════════╡
# │ 43114      ┆ 25031      ┆ 0          ┆ 0036 ┆ … ┆ null ┆ 193        ┆ 0.0           ┆ 20221017   │
# │ 41465      ┆ 10400      ┆ 0          ┆ 0044 ┆ … ┆ null ┆ 84         ┆ 966.0         ┆ 20091117   │
# │ 45111      ┆ 10200      ┆ 0          ┆ 0026 ┆ … ┆ null ┆ 56         ┆ 644.0         ┆ 20110610   │
# │ 48123      ┆ 10700      ┆ 0          ┆ 0576 ┆ … ┆ null ┆ 56         ┆ 667.35        ┆ 20160316   │
# │ 27200      ┆ 10300      ┆ 0          ┆ 0959 ┆ … ┆ null ┆ 176        ┆ 4313.4        ┆ 20130226   │
# └────────────┴────────────┴────────────┴──────┴───┴──────┴────────────┴───────────────┴────────────┘

# %%
df_near_housing = (
    df_housing_permit_parking.select(
        [
            "관리_주택대장_PK",
            "대지_위치",
            "시군구_코드",
            "법정동_코드",
            "대지_구분_코드",
            "번",
            "지",
            "특수지_명",
            "블록",
            "로트",
            "인근_자주식_대수(대)",
            "인근_자주식_면적(㎡)",
            "생성_일자",
        ]
    )
    .filter(near50)
    .groupby(
        [
            "시군구_코드",
            "법정동_코드",
            "대지_구분_코드",
            "번",
            "지",
        ]
    )
    .agg(
        [
            pl.all().sort_by("생성_일자").last(),
        ]
    )
    .collect()
)
len(df_near_housing)
# Out:
# 7

# %%
df_near_housing.head()
# Out:
# shape: (5, 13)
# ┌────────────┬────────────┬────────────┬──────┬───┬──────┬────────────┬───────────────┬────────────┐
# │ 시군구_코  ┆ 법정동_코  ┆ 대지_구분_ ┆ 번   ┆ … ┆ 로트 ┆ 인근_자주  ┆ 인근_자주식_  ┆ 생성_일자  │
# │ 드         ┆ 드         ┆ 코드       ┆ ---  ┆   ┆ ---  ┆ 식_대수(대 ┆ 면적(㎡)      ┆ ---        │
# │ ---        ┆ ---        ┆ ---        ┆ str  ┆   ┆ str  ┆ )          ┆ ---           ┆ str        │
# │ str        ┆ str        ┆ str        ┆      ┆   ┆      ┆ ---        ┆ f64           ┆            │
# │            ┆            ┆            ┆      ┆   ┆      ┆ i64        ┆               ┆            │
# ╞════════════╪════════════╪════════════╪══════╪═══╪══════╪════════════╪═══════════════╪════════════╡
# │ 42760      ┆ 34026      ┆ 0          ┆ 0829 ┆ … ┆ null ┆ 56         ┆ 2538.0        ┆ 20100903   │
# │ 44770      ┆ 25022      ┆ 0          ┆ 0188 ┆ … ┆ null ┆ 64         ┆ 1407.0        ┆ 20200420   │
# │ 41190      ┆ 10600      ┆ 0          ┆ 0048 ┆ … ┆ null ┆ 187        ┆ 66645.35      ┆ 20210901   │
# │ 29200      ┆ 10900      ┆ 0          ┆ 1343 ┆ … ┆ null ┆ 814        ┆ 9559.25       ┆ 20230105   │
# │ 42230      ┆ 10600      ┆ 0          ┆ 0099 ┆ … ┆ null ┆ 68         ┆ 0.0           ┆ 20221130   │
# └────────────┴────────────┴────────────┴──────┴───┴──────┴────────────┴───────────────┴────────────┘

# %% [markdown]
# 인근은 조건을 확인할 수 있는 방법이 없다.

# %%
ev_use_excl_apt = [
    "02007",
    "03000",
    "03001",
    "03002",
    "03005",
    "03006",
    "03007",
    "03008",
    "03009",
    "03010",
    "03011",
    "03012",
    "03013",
    "03014",
    "03015",
    "03016",
    "03017",
    "03018",
    "03019",
    "03020",
    "03021",
    "03022",
    "03023",
    "03024",
    "03025",
    "03026",
    "03027",
    "03028",
    "03029",
    "03100",
    "03102",
    "03103",
    "03104",
    "03105",
    "03107",
    "03108",
    "03109",
    "03112",
    "03113",
    "03114",
    "03199",
    "03999",
    "04000",
    "04001",
    "04002",
    "04003",
    "04004",
    "04005",
    "04006",
    "04008",
    "04009",
    "04010",
    "04011",
    "04012",
    "04014",
    "04016",
    "04018",
    "04019",
    "04020",
    "04021",
    "04024",
    "04030",
    "04031",
    "04032",
    "04033",
    "04034",
    "04035",
    "04036",
    "04037",
    "04038",
    "04039",
    "04100",
    "04101",
    "04102",
    "04103",
    "04104",
    "04105",
    "04106",
    "04107",
    "04108",
    "04199",
    "04200",
    "04201",
    "04202",
    "04203",
    "04204",
    "04205",
    "04206",
    "04207",
    "04208",
    "04299",
    "04300",
    "04302",
    "04303",
    "04304",
    "04305",
    "04306",
    "04307",
    "04308",
    "04399",
    "04400",
    "04401",
    "04402",
    "04403",
    "04404",
    "04405",
    "04499",
    "04999",
    "05000",
    "05100",
    "05102",
    "05103",
    "05104",
    "05105",
    "05106",
    "05107",
    "05108",
    "05199",
    "05200",
    "05201",
    "05202",
    "05203",
    "05204",
    "05205",
    "05299",
    "05300",
    "05301",
    "05302",
    "05303",
    "05304",
    "05305",
    "05306",
    "05399",
    "05400",
    "05401",
    "05402",
    "05403",
    "05404",
    "05405",
    "05406",
    "05407",
    "05408",
    "05499",
    "05500",
    "05501",
    "05502",
    "05503",
    "05599",
    "05999",
    "07000",
    "07100",
    "07101",
    "07102",
    "07103",
    "07104",
    "07105",
    "07199",
    "07201",
    "07209",
    "07210",
    "07211",
    "07212",
    "07300",
    "07301",
    "07302",
    "07399",
    "07999",
    "08000",
    "08001",
    "08004",
    "08007",
    "08008",
    "08999",
    "09000",
    "09100",
    "09101",
    "09102",
    "09103",
    "09104",
    "09105",
    "09107",
    "09109",
    "09199",
    "09200",
    "09201",
    "09202",
    "09299",
    "09999",
    "10000",
    "10002",
    "10003",
    "10005",
    "10100",
    "10101",
    "10102",
    "10103",
    "10104",
    "10105",
    "10106",
    "10107",
    "10199",
    "10200",
    "10201",
    "10202",
    "10299",
    "10300",
    "10301",
    "10302",
    "10303",
    "10399",
    "10999",
    "13000",
    "13001",
    "13003",
    "13004",
    "13005",
    "13006",
    "13007",
    "13008",
    "13009",
    "13010",
    "13011",
    "13012",
    "13013",
    "13100",
    "13101",
    "13102",
    "13103",
    "13104",
    "13105",
    "13106",
    "13107",
    "13108",
    "13109",
    "13110",
    "13999",
    "10203",
    "10204",
    "14000",
    "14100",
    "14101",
    "14102",
    "14103",
    "14199",
    "14200",
    "14201",
    "14202",
    "14203",
    "14204",
    "14299",
    "11101",
    "11200",
    "11204",
    "11205",
    "11299",
    "15000",
    "15001",
    "15100",
    "15101",
    "15102",
    "15103",
    "15199",
    "15200",
    "15201",
    "15202",
    "15203",
    "15204",
    "15205",
    "15299",
    "15999",
    "12002",
    "12003",
    "12004",
    "12005",
    "12006",
    "12007",
    "12008",
    "12009",
    "12999",
    "16000",
    "16001",
    "16002",
    "16005",
    "16007",
    "16009",
    "16010",
    "16011",
    "16012",
    "16013",
    "16999",
    "16003",
    "16004",
    "16006",
    "16008",
    "20000",
    "20001",
    "20002",
    "20003",
    "20004",
    "20005",
    "20006",
    "20007",
    "20008",
    "20009",
    "20010",
    "20999",
    "19007",
    "19008",
    "24000",
    "24002",
    "24003",
    "24004",
    "24100",
    "24101",
    "24102",
    "24103",
    "24104",
    "24105",
    "24999",
    "25000",
    "25001",
    "25999",
    "21003",
    "27000",
    "27001",
    "27002",
    "27003",
    "27004",
    "27005",
    "27007",
    "27008",
    "27009",
    "27999",
]

# %%
### main part

# hierarchy

df_master_building = df_master.select(
    [
        "관리_상위_건축물대장_PK",
        "대장_구분_코드",
        "대장_구분_코드_명",
        "대장_종류_코드",
        "대장_종류_코드_명",
        "대지_위치",
        "도로명_대지_위치",
        "건물_명",
        "시군구_코드",
        "법정동_코드",
        "대지_구분_코드",
        "번",
        "지",
        "관리_건축물대장_PK",
    ]
).filter(
    (pl.col("대장_종류_코드").is_in(["2", "3"]) & pl.col("관리_상위_건축물대장_PK").is_not_null())
)
# df_master_building.head().collect()

# building usage code

df_use = df_floor.select(
    [
        "시군구_코드",
        # "주_용도_코드",
        # "주_용도_코드_명",
        "관리_건축물대장_PK",
    ]
)

df_apt = df_use.filter(pl.col("주_용도_코드") == "02001").groupby("관리_건축물대장_PK").first()
df_apt = df_apt.join(
    df_master_building.select(
        [
            "관리_건축물대장_PK",
            "관리_상위_건축물대장_PK",
        ]
    ),
    "관리_건축물대장_PK",
    "left",
)
df_apt_complex = df_apt.filter(pl.col("관리_상위_건축물대장_PK").is_not_null())
df_apt_single = df_apt.filter(pl.col("관리_상위_건축물대장_PK").is_null())

df_evbuilding = (
    df_use.filter(pl.col("주_용도_코드").is_in(ev_use_excl_apt))
    .groupby("관리_건축물대장_PK")
    .first()
    .join(
        df_master_building.select(
            [
                "관리_건축물대장_PK",
                "관리_상위_건축물대장_PK",
            ]
        ),
        "관리_건축물대장_PK",
        "left",
    )
)
df_evbuilding_complex = df_evbuilding.filter(pl.col("관리_상위_건축물대장_PK").is_not_null())
df_evbuilding_single = df_evbuilding.filter(pl.col("관리_상위_건축물대장_PK").is_null())

# %%
df_apt_complex.head().collect()
# Out:
# shape: (5, 3)
# ┌────────────────────┬─────────────┬─────────────────────────┐
# │ 관리_건축물대장_PK ┆ 시군구_코드 ┆ 관리_상위_건축물대장_PK │
# │ ---                ┆ ---         ┆ ---                     │
# │ str                ┆ str         ┆ str                     │
# ╞════════════════════╪═════════════╪═════════════════════════╡
# │ 41550-17730        ┆ 41550       ┆ 41550-4551              │
# │ 42170-1998         ┆ 42170       ┆ 42170-133               │
# │ 11560-7197         ┆ 11560       ┆ 11560-716               │
# │ 11650-18198        ┆ 11650       ┆ 11650-368               │
# │ 26320-3865         ┆ 26320       ┆ 26320-725               │
# └────────────────────┴─────────────┴─────────────────────────┘

# %%
df_apt_single.head().collect()
# Out:
# shape: (5, 3)
# ┌────────────────────┬─────────────┬─────────────────────────┐
# │ 관리_건축물대장_PK ┆ 시군구_코드 ┆ 관리_상위_건축물대장_PK │
# │ ---                ┆ ---         ┆ ---                     │
# │ str                ┆ str         ┆ str                     │
# ╞════════════════════╪═════════════╪═════════════════════════╡
# │ 28177-100239461    ┆ 28177       ┆ null                    │
# │ 41220-27901        ┆ 41220       ┆ null                    │
# │ 11305-18143        ┆ 11305       ┆ null                    │
# │ 26530-24993        ┆ 26530       ┆ null                    │
# │ 47230-5215         ┆ 47230       ┆ null                    │
# └────────────────────┴─────────────┴─────────────────────────┘

# %%
df_evbuilding_complex.head().collect()
# Out:
# shape: (5, 3)
# ┌────────────────────┬─────────────┬─────────────────────────┐
# │ 관리_건축물대장_PK ┆ 시군구_코드 ┆ 관리_상위_건축물대장_PK │
# │ ---                ┆ ---         ┆ ---                     │
# │ str                ┆ str         ┆ str                     │
# ╞════════════════════╪═════════════╪═════════════════════════╡
# │ 27110-12454        ┆ 27110       ┆ 27110-100177029         │
# │ 29140-130014446    ┆ 29140       ┆ 29140-130014448         │
# │ 41820-100228647    ┆ 41820       ┆ 41820-100228646         │
# │ 29170-54756        ┆ 29170       ┆ 29170-503               │
# │ 41220-100300452    ┆ 41220       ┆ 41220-100300450         │
# └────────────────────┴─────────────┴─────────────────────────┘

# %%
df_evbuilding_single.head().collect()
# Out:
# shape: (5, 3)
# ┌────────────────────┬─────────────┬─────────────────────────┐
# │ 관리_건축물대장_PK ┆ 시군구_코드 ┆ 관리_상위_건축물대장_PK │
# │ ---                ┆ ---         ┆ ---                     │
# │ str                ┆ str         ┆ str                     │
# ╞════════════════════╪═════════════╪═════════════════════════╡
# │ 43113-2000283554   ┆ 43113       ┆ null                    │
# │ 31110-20530        ┆ 31110       ┆ null                    │
# │ 41410-100221420    ┆ 41410       ┆ null                    │
# │ 44270-100248868    ┆ 44270       ┆ null                    │
# │ 41480-18819        ┆ 41480       ┆ null                    │
# └────────────────────┴─────────────┴─────────────────────────┘

# %%
### apt. with 100 units

# test site df

df_site.filter(pl.col("관리_건축물대장_PK") == "26320-587").collect()
# Out:
# shape: (1, 64)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 대장_구분_ ┆ 대장_구분_ ┆ 대장_종류_ ┆ 대장_종류_ ┆ … ┆ 지능형_건  ┆ 지능형_건  ┆ 생성_일자  ┆ 관리_건축  │
# │ 코드       ┆ 코드_명    ┆ 코드       ┆ 코드_명    ┆   ┆ 축물_등급  ┆ 축물_인증  ┆ ---        ┆ 물대장_PK  │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ 점수       ┆ str        ┆ ---        │
# │ str        ┆ str        ┆ str        ┆ str        ┆   ┆ str        ┆ ---        ┆            ┆ str        │
# │            ┆            ┆            ┆            ┆   ┆            ┆ i64        ┆            ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2          ┆ 집합       ┆ 1          ┆ 총괄표제부 ┆ … ┆ null       ┆ 0          ┆ 20171118   ┆ 26320-587  │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
col_site = [
    "시군구_코드",
    "주_용도_코드",
    "주_용도_코드_명",
    "세대_수(세대)",
    "총_주차_수",
    "옥내_기계식_대수(대)",
    "옥외_기계식_대수(대)",
    "옥내_자주식_대수(대)",
    "옥외_자주식_대수(대)",
    "사용승인_일",
    "관리_건축물대장_PK",
]

col_dong = [
    "시군구_코드",
    # "주_용도_코드",
    # "주_용도_코드_명",
    "세대_수(세대)",
    "옥내_기계식_대수(대)",
    "옥외_기계식_대수(대)",
    "옥내_자주식_대수(대)",
    "옥외_자주식_대수(대)",
    "사용승인_일",
    "관리_건축물대장_PK",
]

col_dong_with_use = [
    "시군구_코드",
    "주_용도_코드",
    "주_용도_코드_명",
    "세대_수(세대)",
    "옥내_기계식_대수(대)",
    "옥외_기계식_대수(대)",
    "옥내_자주식_대수(대)",
    "옥외_자주식_대수(대)",
    "사용승인_일",
    "관리_건축물대장_PK",
]

# %%
# test dong df

df_apt_complex.filter(pl.col("관리_상위_건축물대장_PK") == "26320-587").join(
    df_dong, "관리_건축물대장_PK"
).groupby("관리_상위_건축물대장_PK").agg(
    [
        pl.first("시군구_코드"),
        pl.sum("세대_수(세대)"),
        pl.sum("옥내_자주식_대수(대)"),
        pl.sum("옥외_자주식_대수(대)"),
        pl.max("사용승인_일"),
    ]
).head(
    2
).collect()
# Out:
# shape: (1, 6)
# ┌──────────────────┬─────────────┬───────────────┬─────────────────┬─────────────────┬─────────────┐
# │ 관리_상위_건축물 ┆ 시군구_코드 ┆ 세대_수(세대) ┆ 옥내_자주식_대  ┆ 옥외_자주식_대  ┆ 사용승인_일 │
# │ 대장_PK          ┆ ---         ┆ ---           ┆ 수(대)          ┆ 수(대)          ┆ ---         │
# │ ---              ┆ str         ┆ i64           ┆ ---             ┆ ---             ┆ str         │
# │ str              ┆             ┆               ┆ i64             ┆ i64             ┆             │
# ╞══════════════════╪═════════════╪═══════════════╪═════════════════╪═════════════════╪═════════════╡
# │ 26320-587        ┆ 26320       ┆ 532           ┆ 0               ┆ 0               ┆ 19950527    │
# └──────────────────┴─────────────┴───────────────┴─────────────────┴─────────────────┴─────────────┘

# %%
df_apt_complex_site = df_apt_complex.join(df_dong.select(col_dong), "관리_건축물대장_PK")
df_apt_complex_site = df_apt_complex_site.groupby("관리_상위_건축물대장_PK").agg(
    [
        pl.first("시군구_코드"),
        # pl.first("주_용도_코드"),
        # pl.first("주_용도_코드_명"),
        pl.sum("세대_수(세대)"),
        pl.sum("옥내_기계식_대수(대)"),
        pl.sum("옥외_기계식_대수(대)"),
        pl.sum("옥내_자주식_대수(대)"),
        pl.sum("옥외_자주식_대수(대)"),
        pl.max("사용승인_일"),
    ]
)
df_apt_complex_site = df_apt_complex_site.join(
    df_site.select(col_site),
    left_on="관리_상위_건축물대장_PK",
    right_on="관리_건축물대장_PK",
    suffix="_site",
)
df_apt_complex_site = df_apt_complex_site.filter((pl.col("주_용도_코드") == "02000"))

# 100 units cut

df_apt_complex_site = df_apt_complex_site.filter(
    (pl.col("세대_수(세대)_site") >= 100)
    | ((pl.col("세대_수(세대)_site") == 0) & (pl.col("세대_수(세대)") >= 100))
)


df_apt_complex_site = df_apt_complex_site.with_columns(
    [
        (
            pl.when(pl.col("옥내_자주식_대수(대)_site") + pl.col("옥외_자주식_대수(대)_site") > 0)
            .then(pl.col("옥내_자주식_대수(대)_site") + pl.col("옥외_자주식_대수(대)_site"))
            .otherwise(pl.col("옥내_자주식_대수(대)") + pl.col("옥외_자주식_대수(대)"))
            .alias("옥내외_자주식_대수")
        ),
        (
            pl.when(
                (pl.col("총_주차_수") > 0)
                & (
                    pl.col("총_주차_수")
                    >= pl.col("옥내_기계식_대수(대)_site")
                    + pl.col("옥외_기계식_대수(대)_site")
                    + pl.col("옥내_자주식_대수(대)_site")
                    + pl.col("옥외_자주식_대수(대)_site")
                )
            )
            .then(pl.col("총_주차_수"))
            .when(
                pl.col("옥내_기계식_대수(대)_site")
                + pl.col("옥외_기계식_대수(대)_site")
                + pl.col("옥내_자주식_대수(대)_site")
                + pl.col("옥외_자주식_대수(대)_site")
                > pl.col("총_주차_수")
            )
            .then(
                pl.col("옥내_기계식_대수(대)_site")
                + pl.col("옥외_기계식_대수(대)_site")
                + pl.col("옥내_자주식_대수(대)_site")
                + pl.col("옥외_자주식_대수(대)_site")
            )
            .otherwise(
                pl.col("옥내_기계식_대수(대)")
                + pl.col("옥외_기계식_대수(대)")
                + pl.col("옥내_자주식_대수(대)")
                + pl.col("옥외_자주식_대수(대)")
            )
            .alias("총_주차대수")
        ),
    ]
)

df_apt_complex_site = df_apt_complex_site.filter(pl.col("옥내외_자주식_대수") >= 50)
df_apt_complex_site = df_apt_complex_site.with_columns(
    (pl.col("옥내외_자주식_대수") * 0.02).round().cast(pl.Int64).alias("전기차_기축_대수")
)
df_apt_complex_site = df_apt_complex_site.with_columns(
    pl.when((pl.col("사용승인_일") >= "20130000"))
    .then((pl.col("옥내외_자주식_대수") * 0.05).round())
    .otherwise(0)
    .cast(pl.Int64)
    .alias("전기차_신축_최근10년_대수")
)


df_apt_complex_result = df_apt_complex_site.collect()
df_apt_complex_result.head(20)
# Out:
# shape: (20, 22)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 관리_상위_ ┆ 시군구_코  ┆ 세대_수(세 ┆ 옥내_기계  ┆ … ┆ 옥내외_자  ┆ 총_주차대  ┆ 전기차_기  ┆ 전기차_신  │
# │ 건축물대장 ┆ 드         ┆ 대)        ┆ 식_대수(대 ┆   ┆ 주식_대수  ┆ 수         ┆ 축_대수    ┆ 축_최근10  │
# │ _PK        ┆ ---        ┆ ---        ┆ )          ┆   ┆ ---        ┆ ---        ┆ ---        ┆ 년_대수    │
# │ ---        ┆ str        ┆ i64        ┆ ---        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ ---        │
# │ str        ┆            ┆            ┆ i64        ┆   ┆            ┆            ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 11110-1001 ┆ 11110      ┆ 710        ┆ 0          ┆ … ┆ 1480       ┆ 1480       ┆ 30         ┆ 0          │
# │ 80150      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11110-1001 ┆ 11110      ┆ 810        ┆ 0          ┆ … ┆ 1105       ┆ 1108       ┆ 23         ┆ 0          │
# │ 82070      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11110-1001 ┆ 11110      ┆ 416        ┆ 0          ┆ … ┆ 514        ┆ 519        ┆ 11         ┆ 0          │
# │ 83699      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11110-1001 ┆ 11110      ┆ 288        ┆ 0          ┆ … ┆ 342        ┆ 342        ┆ 7          ┆ 0          │
# │ 85100      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 11110-849  ┆ 11110      ┆ 172        ┆ 0          ┆ … ┆ 170        ┆ 170        ┆ 4          ┆ 0          │
# │ 11140-1001 ┆ 11140      ┆ 1870       ┆ 0          ┆ … ┆ 2902       ┆ 2902       ┆ 59         ┆ 0          │
# │ 92588      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11140-1002 ┆ 11140      ┆ 181        ┆ 0          ┆ … ┆ 221        ┆ 221        ┆ 5          ┆ 0          │
# │ 07433      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11140-1002 ┆ 11140      ┆ 784        ┆ 0          ┆ … ┆ 968        ┆ 968        ┆ 20         ┆ 0          │
# │ 09042      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_apt_single_dong = df_apt_single.join(
    df_dong.select(col_dong_with_use), "관리_건축물대장_PK"
)  # with use code
df_apt_single_dong = df_apt_single_dong.filter((pl.col("주_용도_코드") == "02000"))
df_apt_single_dong = df_apt_single_dong.filter((pl.col("세대_수(세대)") >= 100))
df_apt_single_dong = df_apt_single_dong.with_columns(
    [
        (pl.col("옥내_자주식_대수(대)") + pl.col("옥외_자주식_대수(대)")).alias("옥내외_자주식_대수"),
        (
            pl.col("옥내_기계식_대수(대)")
            + pl.col("옥외_기계식_대수(대)")
            + pl.col("옥내_자주식_대수(대)")
            + pl.col("옥외_자주식_대수(대)")
        ).alias("총_주차대수"),
    ]
)

df_apt_single_dong = df_apt_single_dong.filter(pl.col("옥내외_자주식_대수") >= 50)
df_apt_single_dong = df_apt_single_dong.with_columns(
    (pl.col("옥내외_자주식_대수") * 0.02).round().cast(pl.Int64).alias("전기차_기축_대수")
)
df_apt_single_dong = df_apt_single_dong.with_columns(
    pl.when((pl.col("사용승인_일") >= "20130000"))
    .then((pl.col("옥내외_자주식_대수") * 0.05).round())
    .otherwise(0)
    .cast(pl.Int64)
    .alias("전기차_신축_최근10년_대수")
)

df_apt_single_result = df_apt_single_dong.collect()
df_apt_single_result
# Out:
# shape: (2_024, 16)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 관리_건축  ┆ 시군구_코  ┆ 관리_상위_ ┆ 시군구_코  ┆ … ┆ 옥내외_자  ┆ 총_주차대  ┆ 전기차_기  ┆ 전기차_신  │
# │ 물대장_PK  ┆ 드         ┆ 건축물대장 ┆ 드_right   ┆   ┆ 주식_대수  ┆ 수         ┆ 축_대수    ┆ 축_최근10  │
# │ ---        ┆ ---        ┆ _PK        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ 년_대수    │
# │ str        ┆ str        ┆ ---        ┆ str        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ ---        │
# │            ┆            ┆ str        ┆            ┆   ┆            ┆            ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 11110-1000 ┆ 11110      ┆ null       ┆ 11110      ┆ … ┆ 257        ┆ 257        ┆ 6          ┆ 13         │
# │ 0000000000 ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 00166233   ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11110-1046 ┆ 11110      ┆ null       ┆ 11110      ┆ … ┆ 172        ┆ 172        ┆ 4          ┆ 0          │
# │ 0          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11110-1326 ┆ 11110      ┆ null       ┆ 11110      ┆ … ┆ 228        ┆ 228        ┆ 5          ┆ 0          │
# │ 7          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11110-1418 ┆ 11110      ┆ null       ┆ 11110      ┆ … ┆ 326        ┆ 326        ┆ 7          ┆ 0          │
# │ 0          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 30140-1002 ┆ 30140      ┆ null       ┆ 30140      ┆ … ┆ 213        ┆ 243        ┆ 5          ┆ 11         │
# │ 23132      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 30140-1002 ┆ 30140      ┆ null       ┆ 30140      ┆ … ┆ 190        ┆ 190        ┆ 4          ┆ 10         │
# │ 24532      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 30140-1002 ┆ 30140      ┆ null       ┆ 30140      ┆ … ┆ 117        ┆ 117        ┆ 3          ┆ 6          │
# │ 26332      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 30140-1119 ┆ 30140      ┆ null       ┆ 30140      ┆ … ┆ 306        ┆ 306        ┆ 7          ┆ 0          │
# │ 8          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
no_ev_use = [
    "01000",
    "02000",
    "06000",
    "11000",
    "12000",
    "17000",
    "18000",
    "19000",
    "21000",
    "22000",
    "23000",
    "26000",
    "29000",
    "28000",
]

# %%
### 부설주차장 excluding apt.

df_evbuilding_complex_site = df_evbuilding_complex.join(
    df_dong.select(col_dong), "관리_건축물대장_PK"
)

# filter apt.
df_evbuilding_complex_site = df_evbuilding_complex_site.join(
    df_apt_complex_result.lazy().select(["관리_상위_건축물대장_PK", "시군구_코드"]),
    "관리_상위_건축물대장_PK",
    how="left",
    suffix="_apt",
).filter(pl.col("시군구_코드_apt").is_null())

df_evbuilding_complex_site = df_evbuilding_complex_site.groupby("관리_상위_건축물대장_PK").agg(
    [
        pl.first("시군구_코드"),
        # pl.first("주_용도_코드"),
        # pl.first("주_용도_코드_명"),
        pl.sum("세대_수(세대)"),
        pl.sum("옥내_기계식_대수(대)"),
        pl.sum("옥외_기계식_대수(대)"),
        pl.sum("옥내_자주식_대수(대)"),
        pl.sum("옥외_자주식_대수(대)"),
        pl.max("사용승인_일"),
    ]
)
df_evbuilding_complex_site = df_evbuilding_complex_site.join(
    df_site.select(col_site),
    left_on="관리_상위_건축물대장_PK",
    right_on="관리_건축물대장_PK",
    suffix="_site",
)

# filter no ev use
df_evbuilding_complex_site = df_evbuilding_complex_site.filter(
    ~(pl.col("주_용도_코드").is_in(no_ev_use))
)

df_evbuilding_complex_site = df_evbuilding_complex_site.with_columns(
    [
        (
            pl.when(pl.col("옥내_자주식_대수(대)_site") + pl.col("옥외_자주식_대수(대)_site") > 0)
            .then(pl.col("옥내_자주식_대수(대)_site") + pl.col("옥외_자주식_대수(대)_site"))
            .otherwise(pl.col("옥내_자주식_대수(대)") + pl.col("옥외_자주식_대수(대)"))
            .alias("옥내외_자주식_대수")
        ),
        (
            pl.when(
                (pl.col("총_주차_수") > 0)
                & (
                    pl.col("총_주차_수")
                    >= pl.col("옥내_기계식_대수(대)_site")
                    + pl.col("옥외_기계식_대수(대)_site")
                    + pl.col("옥내_자주식_대수(대)_site")
                    + pl.col("옥외_자주식_대수(대)_site")
                )
            )
            .then(pl.col("총_주차_수"))
            .when(
                pl.col("옥내_기계식_대수(대)_site")
                + pl.col("옥외_기계식_대수(대)_site")
                + pl.col("옥내_자주식_대수(대)_site")
                + pl.col("옥외_자주식_대수(대)_site")
                > pl.col("총_주차_수")
            )
            .then(
                pl.col("옥내_기계식_대수(대)_site")
                + pl.col("옥외_기계식_대수(대)_site")
                + pl.col("옥내_자주식_대수(대)_site")
                + pl.col("옥외_자주식_대수(대)_site")
            )
            .otherwise(
                pl.col("옥내_기계식_대수(대)")
                + pl.col("옥외_기계식_대수(대)")
                + pl.col("옥내_자주식_대수(대)")
                + pl.col("옥외_자주식_대수(대)")
            )
            .alias("총_주차대수")
        ),
    ]
)


df_evbuilding_complex_site = df_evbuilding_complex_site.filter(
    pl.col("옥내외_자주식_대수") >= 50
)
df_evbuilding_complex_site = df_evbuilding_complex_site.with_columns(
    (pl.col("옥내외_자주식_대수") * 0.02).round().cast(pl.Int64).alias("전기차_기축_대수")
)
df_evbuilding_complex_site = df_evbuilding_complex_site.with_columns(
    pl.when((pl.col("사용승인_일") >= "20130000"))
    .then((pl.col("옥내외_자주식_대수") * 0.05).round())
    .otherwise(0)
    .cast(pl.Int64)
    .alias("전기차_신축_최근10년_대수")
)

df_evbuilding_complex_result = df_evbuilding_complex_site.collect()
df_evbuilding_complex_result.head(20)
# Out:
# shape: (20, 22)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 관리_상위_ ┆ 시군구_코  ┆ 세대_수(세 ┆ 옥내_기계  ┆ … ┆ 옥내외_자  ┆ 총_주차대  ┆ 전기차_기  ┆ 전기차_신  │
# │ 건축물대장 ┆ 드         ┆ 대)        ┆ 식_대수(대 ┆   ┆ 주식_대수  ┆ 수         ┆ 축_대수    ┆ 축_최근10  │
# │ _PK        ┆ ---        ┆ ---        ┆ )          ┆   ┆ ---        ┆ ---        ┆ ---        ┆ 년_대수    │
# │ ---        ┆ str        ┆ i64        ┆ ---        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ ---        │
# │ str        ┆            ┆            ┆ i64        ┆   ┆            ┆            ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 41590-3340 ┆ 41590      ┆ 0          ┆ 0          ┆ … ┆ 95         ┆ 95         ┆ 2          ┆ 5          │
# │ 30200-161  ┆ 30200      ┆ 0          ┆ 0          ┆ … ┆ 328        ┆ 328        ┆ 7          ┆ 17         │
# │ 48170-1002 ┆ 48170      ┆ 0          ┆ 0          ┆ … ┆ 110        ┆ 110        ┆ 3          ┆ 6          │
# │ 61347      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11320-157  ┆ 11320      ┆ 217        ┆ 0          ┆ … ┆ 176        ┆ 176        ┆ 4          ┆ 0          │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 41210-36   ┆ 41210      ┆ 0          ┆ 0          ┆ … ┆ 50         ┆ 50         ┆ 1          ┆ 3          │
# │ 48330-252  ┆ 48330      ┆ 0          ┆ 0          ┆ … ┆ 244        ┆ 244        ┆ 5          ┆ 0          │
# │ 11290-1242 ┆ 11290      ┆ 0          ┆ 0          ┆ … ┆ 57         ┆ 57         ┆ 2          ┆ 3          │
# │ 47850-2631 ┆ 47850      ┆ 0          ┆ 0          ┆ … ┆ 50         ┆ 50         ┆ 1          ┆ 0          │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_site.filter((pl.col("관리_건축물대장_PK") == "41135-100204512")).collect()

# 뭐지?
# Out:
# shape: (1, 64)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 대장_구분_ ┆ 대장_구분_ ┆ 대장_종류_ ┆ 대장_종류_ ┆ … ┆ 지능형_건  ┆ 지능형_건  ┆ 생성_일자  ┆ 관리_건축  │
# │ 코드       ┆ 코드_명    ┆ 코드       ┆ 코드_명    ┆   ┆ 축물_등급  ┆ 축물_인증  ┆ ---        ┆ 물대장_PK  │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ 점수       ┆ str        ┆ ---        │
# │ str        ┆ str        ┆ str        ┆ str        ┆   ┆ str        ┆ ---        ┆            ┆ str        │
# │            ┆            ┆            ┆            ┆   ┆            ┆ i64        ┆            ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 2          ┆ 집합       ┆ 1          ┆ 총괄표제부 ┆ … ┆ null       ┆ 0          ┆ 20191212   ┆ 41135-1002 │
# │            ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆ 04512      │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_evbuilding_complex_result.filter((pl.col("주_용도_코드") == "02000")).head()
# Out:
# shape: (0, 22)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 관리_상위_ ┆ 시군구_코  ┆ 세대_수(세 ┆ 옥내_기계  ┆ … ┆ 옥내외_자  ┆ 총_주차대  ┆ 전기차_기  ┆ 전기차_신  │
# │ 건축물대장 ┆ 드         ┆ 대)        ┆ 식_대수(대 ┆   ┆ 주식_대수  ┆ 수         ┆ 축_대수    ┆ 축_최근10  │
# │ _PK        ┆ ---        ┆ ---        ┆ )          ┆   ┆ ---        ┆ ---        ┆ ---        ┆ 년_대수    │
# │ ---        ┆ str        ┆ i64        ┆ ---        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ ---        │
# │ str        ┆            ┆            ┆ i64        ┆   ┆            ┆            ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_evbuilding_single_dong = df_evbuilding_single.join(
    df_dong.select(col_dong_with_use), "관리_건축물대장_PK"
)  # with use code
df_evbuilding_single_dong = df_evbuilding_single_dong.filter(
    ~(pl.col("주_용도_코드").is_in(no_ev_use))
)

df_evbuilding_single_dong = df_evbuilding_single_dong.with_columns(
    [
        (pl.col("옥내_자주식_대수(대)") + pl.col("옥외_자주식_대수(대)")).alias("옥내외_자주식_대수"),
        (
            pl.col("옥내_기계식_대수(대)")
            + pl.col("옥외_기계식_대수(대)")
            + pl.col("옥내_자주식_대수(대)")
            + pl.col("옥외_자주식_대수(대)")
        ).alias("총_주차대수"),
    ]
)

df_evbuilding_single_dong = df_evbuilding_single_dong.filter(pl.col("옥내외_자주식_대수") >= 50)
df_evbuilding_single_dong = df_evbuilding_single_dong.with_columns(
    (pl.col("옥내외_자주식_대수") * 0.02).round().cast(pl.Int64).alias("전기차_기축_대수")
)
df_evbuilding_single_dong = df_evbuilding_single_dong.with_columns(
    pl.when((pl.col("사용승인_일") >= "20130000"))
    .then((pl.col("옥내외_자주식_대수") * 0.05).round())
    .otherwise(0)
    .cast(pl.Int64)
    .alias("전기차_신축_최근10년_대수")
)

df_evbuilding_single_result = df_evbuilding_single_dong.collect()
df_evbuilding_single_result.head()
# Out:
# shape: (5, 16)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 관리_건축  ┆ 시군구_코  ┆ 관리_상위_ ┆ 시군구_코  ┆ … ┆ 옥내외_자  ┆ 총_주차대  ┆ 전기차_기  ┆ 전기차_신  │
# │ 물대장_PK  ┆ 드         ┆ 건축물대장 ┆ 드_right   ┆   ┆ 주식_대수  ┆ 수         ┆ 축_대수    ┆ 축_최근10  │
# │ ---        ┆ ---        ┆ _PK        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ 년_대수    │
# │ str        ┆ str        ┆ ---        ┆ str        ┆   ┆ i64        ┆ i64        ┆ i64        ┆ ---        │
# │            ┆            ┆ str        ┆            ┆   ┆            ┆            ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 43130-1381 ┆ 43130      ┆ null       ┆ 43130      ┆ … ┆ 66         ┆ 66         ┆ 2          ┆ 0          │
# │ 1          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 41111-1468 ┆ 41111      ┆ null       ┆ 41111      ┆ … ┆ 53         ┆ 53         ┆ 2          ┆ 0          │
# │ 5          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 11680-1345 ┆ 11680      ┆ null       ┆ 11680      ┆ … ┆ 69         ┆ 69         ┆ 2          ┆ 0          │
# │ 3          ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 26440-1002 ┆ 26440      ┆ null       ┆ 26440      ┆ … ┆ 61         ┆ 61         ┆ 2          ┆ 0          │
# │ 37233      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 29200-1003 ┆ 29200      ┆ null       ┆ 29200      ┆ … ┆ 82         ┆ 234        ┆ 2          ┆ 5          │
# │ 52886      ┆            ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
# results
from pathlib import Path

Path("output/parking").mkdir(parents=True, exist_ok=True)


dfs = [
    (df_near_building, "near_building"),
    (df_near_housing, "near_housing"),
    (df_apt_complex_result, "apt_complex"),
    (df_apt_single_result, "apt_single"),
    (df_evbuilding_complex_result, "evbuilding_complex"),
    (df_evbuilding_single_result, "evbuilding_single"),
]

for df, filename in dfs:
    df.to_pandas().to_csv(
        f"output/parking/{filename}.csv", encoding="utf-8-sig", index=False
    )

# %% [markdown]
# ## 노외주차장

# %%
import pandas as pd

df = pd.read_excel("data/parking/전국주차장정보표준데이터-20230810.xls", header=1, engine="xlrd")
df: pl.DataFrame = pl.from_pandas(df)

# %%
df_offroad = df.filter(pl.col("주차장유형") == "노외")
len(df_offroad)
# Out:
# 10762

# %%
df_offroad.null_count()
# Out:
# shape: (1, 33)
# ┌────────────┬────────────┬────────────┬────────────┬───┬──────┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 경도 ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---  ┆ 일자       ┆ 드         ┆ ---        │
# │ ---        ┆ u32        ┆ u32        ┆ u32        ┆   ┆ u32  ┆ ---        ┆ ---        ┆ u32        │
# │ u32        ┆            ┆            ┆            ┆   ┆      ┆ u32        ┆ u32        ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪══════╪════════════╪════════════╪════════════╡
# │ 0          ┆ 0          ┆ 0          ┆ 0          ┆ … ┆ 1930 ┆ 0          ┆ 0          ┆ 0          │
# └────────────┴────────────┴────────────┴────────────┴───┴──────┴────────────┴────────────┴────────────┘

# %%
df_offroad.filter(pl.col("소재지도로명주소").is_null() & pl.col("소재지지번주소").is_null())
# Out:
# shape: (0, 33)
# ┌────────────┬────────────┬────────────┬────────────┬───┬──────┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 경도 ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---  ┆ 일자       ┆ 드         ┆ ---        │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ f64  ┆ ---        ┆ ---        ┆ str        │
# │ str        ┆            ┆            ┆            ┆   ┆      ┆ str        ┆ str        ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪══════╪════════════╪════════════╪════════════╡
# └────────────┴────────────┴────────────┴────────────┴───┴──────┴────────────┴────────────┴────────────┘

# %% [markdown]
# 도로명주소, 지번주소 둘 중 하나는 있다.

# %%
df_offroad.sum()
# Out:
# shape: (1, 33)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 경 ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ 도 ┆ 일자       ┆ 드         ┆ ---        │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ - ┆ ---        ┆ ---        ┆ str        │
# │ str        ┆            ┆            ┆            ┆   ┆ - ┆ str        ┆ str        ┆            │
# │            ┆            ┆            ┆            ┆   ┆ - ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ f ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 4 ┆            ┆            ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══╪════════════╪════════════╪════════════╡
# │ null       ┆ null       ┆ null       ┆ null       ┆ … ┆ 1 ┆ null       ┆ null       ┆ null       │
# │            ┆            ┆            ┆            ┆   ┆ . ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 7 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ e ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴───┴────────────┴────────────┴────────────┘

# %%
len(df_offroad)
# Out:
# 10762

# %%
df_offroad.columns
# Out:
# ['주차장관리번호',
#  '주차장명',
#  '주차장구분',
#  '주차장유형',
#  '소재지도로명주소',
#  '소재지지번주소',
#  '주차구획수',
#  '급지구분',
#  '부제시행구분',
#  '운영요일',
#  '평일운영시작시각',
#  '평일운영종료시각',
#  '토요일운영시작시각',
#  '토요일운영종료시각',
#  '공휴일운영시작시각',
#  '공휴일운영종료시각',
#  '요금정보',
#  '주차기본시간',
#  '주차기본요금',
#  '추가단위시간',
#  '추가단위요금',
#  '1일주차권요금적용시간',
#  '1일주차권요금',
#  '월정기권요금',
#  '결제방법',
#  '특기사항',
#  '관리기관명',
#  '전화번호',
#  '위도',
#  '경도',
#  '데이터기준일자',
#  '제공기관코드',
#  '제공기관명']

# %%
df_offroad.head()
# Out:
# shape: (5, 33)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 경 ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ 도 ┆ 일자       ┆ 드         ┆ ---        │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ - ┆ ---        ┆ ---        ┆ str        │
# │ str        ┆            ┆            ┆            ┆   ┆ - ┆ str        ┆ str        ┆            │
# │            ┆            ┆            ┆            ┆   ┆ - ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ f ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 4 ┆            ┆            ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══╪════════════╪════════════╪════════════╡
# │ 294-2-0000 ┆ 관광주차장 ┆ 공영       ┆ 노외       ┆ … ┆ 1 ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   │
# │ 01         ┆            ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆ 부여군     │
# │            ┆            ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ . ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 4 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 5 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 3 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │ 294-2-0000 ┆ 정림사지주 ┆ 공영       ┆ 노외       ┆ … ┆ 1 ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   │
# │ 02         ┆ 차장       ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆ 부여군     │
# │            ┆            ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ . ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 8 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 8 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │ 294-2-0000 ┆ 서동공원(  ┆ 공영       ┆ 노외       ┆ … ┆ 1 ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   │
# │ 03         ┆ 동문주차장 ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆ 부여군     │
# │            ┆ )          ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ . ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 3 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 1 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 8 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 7 ┆            ┆            ┆            │
# │ 294-2-0000 ┆ 서동공원(  ┆ 공영       ┆ 노외       ┆ … ┆ 1 ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   │
# │ 04         ┆ 서문주차장 ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆ 부여군     │
# │            ┆ )          ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ . ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 0 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 5 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆            │
# │ 294-2-0000 ┆ 서동공원(  ┆ 공영       ┆ 노외       ┆ … ┆ 1 ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   │
# │ 05         ┆ 임시주차장 ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆ 부여군     │
# │            ┆ )          ┆            ┆            ┆   ┆ 6 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ . ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 0 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 9 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 5 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 0 ┆            ┆            ┆            │
# │            ┆            ┆            ┆            ┆   ┆ 2 ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴───┴────────────┴────────────┴────────────┘

# %%
df_offroad = df_offroad.select(
    [
        "주차장관리번호",
        "주차장명",
        "주차장구분",
        "주차장유형",
        "소재지도로명주소",
        "소재지지번주소",
        "주차구획수",
        "급지구분",
        # "부제시행구분",
        # "운영요일",
        # "평일운영시작시각",
        # "평일운영종료시각",
        # "토요일운영시작시각",
        # "토요일운영종료시각",
        # "공휴일운영시작시각",
        # "공휴일운영종료시각",
        # "요금정보",
        # "주차기본시간",
        # "주차기본요금",
        # "추가단위시간",
        # "추가단위요금",
        # "1일주차권요금적용시간",
        # "1일주차권요금",
        # "월정기권요금",
        # "결제방법",
        "특기사항",
        "관리기관명",
        "전화번호",
        "위도",
        "경도",
        "데이터기준일자",
        "제공기관코드",
        "제공기관명",
    ]
).with_columns((pl.col("주차구획수") * 0.05).round().cast(pl.Int64).alias("전기차전용주차구획수"))
df_offroad.head()
# Out:
# shape: (5, 17)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 ┆ 전기차전용 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ 일자       ┆ 드         ┆ ---        ┆ 주차구획수 │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ str        ┆ ---        │
# │ str        ┆            ┆            ┆            ┆   ┆ str        ┆ str        ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 294-2-0000 ┆ 관광주차장 ┆ 공영       ┆ 노외       ┆ … ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   ┆ 5          │
# │ 01         ┆            ┆            ┆            ┆   ┆            ┆            ┆ 부여군     ┆            │
# │ 294-2-0000 ┆ 정림사지주 ┆ 공영       ┆ 노외       ┆ … ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   ┆ 6          │
# │ 02         ┆ 차장       ┆            ┆            ┆   ┆            ┆            ┆ 부여군     ┆            │
# │ 294-2-0000 ┆ 서동공원(  ┆ 공영       ┆ 노외       ┆ … ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   ┆ 3          │
# │ 03         ┆ 동문주차장 ┆            ┆            ┆   ┆            ┆            ┆ 부여군     ┆            │
# │            ┆ )          ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 294-2-0000 ┆ 서동공원(  ┆ 공영       ┆ 노외       ┆ … ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   ┆ 7          │
# │ 04         ┆ 서문주차장 ┆            ┆            ┆   ┆            ┆            ┆ 부여군     ┆            │
# │            ┆ )          ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# │ 294-2-0000 ┆ 서동공원(  ┆ 공영       ┆ 노외       ┆ … ┆ 2023-05-10 ┆ 4570000    ┆ 충청남도   ┆ 6          │
# │ 05         ┆ 임시주차장 ┆            ┆            ┆   ┆            ┆            ┆ 부여군     ┆            │
# │            ┆ )          ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_offroad.sum()
# Out:
# shape: (1, 17)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 ┆ 전기차전용 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ 일자       ┆ 드         ┆ ---        ┆ 주차구획수 │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ str        ┆ ---        │
# │ str        ┆            ┆            ┆            ┆   ┆ str        ┆ str        ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ null       ┆ null       ┆ null       ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ 40217      │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_offroad.min()
# Out:
# shape: (1, 17)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 ┆ 전기차전용 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ 일자       ┆ 드         ┆ ---        ┆ 주차구획수 │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ str        ┆ ---        │
# │ str        ┆            ┆            ┆            ┆   ┆ str        ┆ str        ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 000-2-0000 ┆ (구)3번종  ┆ 공영       ┆ 노외       ┆ … ┆ 2016-06-01 ┆ 3000000    ┆ 강북구도시 ┆ 0          │
# │ 25         ┆ 점 역동    ┆            ┆            ┆   ┆            ┆            ┆ 관리공단   ┆            │
# │            ┆ 공영주차장 ┆            ┆            ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df_offroad.max()
# Out:
# shape: (1, 17)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ 주차장관리 ┆ 주차장명   ┆ 주차장구분 ┆ 주차장유형 ┆ … ┆ 데이터기준 ┆ 제공기관코 ┆ 제공기관명 ┆ 전기차전용 │
# │ 번호       ┆ ---        ┆ ---        ┆ ---        ┆   ┆ 일자       ┆ 드         ┆ ---        ┆ 주차구획수 │
# │ ---        ┆ str        ┆ str        ┆ str        ┆   ┆ ---        ┆ ---        ┆ str        ┆ ---        │
# │ str        ┆            ┆            ┆            ┆   ┆ str        ┆ str        ┆            ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 418-2-0000 ┆ 힐튼장 앞  ┆ 민영       ┆ 노외       ┆ … ┆ 2023-07-14 ┆ B553949    ┆ 포항시시설 ┆ 140        │
# │ 63         ┆            ┆            ┆            ┆   ┆            ┆            ┆ 관리공단   ┆            │
# └────────────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
import numpy as np

# Define bins and labels for them
bins = [0, 20, 50, 100, 200, 400, np.inf]
labels = ["20대 이하", "50대 이하", "100대 이하", "200대 이하", "400대 이하", "400대 초과"]

df = df_offroad.to_pandas()
df["규모"] = pd.cut(df["주차구획수"], bins=bins, labels=labels)
df.head()
# Out:
#         주차장관리번호         주차장명 주차장구분 주차장유형                소재지도로명주소  \
# 0  294-2-000001        관광주차장    공영    노외  충청남도 부여군 부여읍 성왕로 247-9
# 1  294-2-000002      정림사지주차장    공영    노외     충청남도 부여군 부여읍 정림로 83
# 2  294-2-000003  서동공원(동문주차장)    공영    노외                    None
# 3  294-2-000004  서동공원(서문주차장)    공영    노외                    None
# 4  294-2-000005  서동공원(임시주차장)    공영    노외                    None
#
#                   소재지지번주소  주차구획수 급지구분  특기사항      관리기관명          전화번호  \
# 0     충청남도 부여군 부여읍 관북리 77    100    1  None  충청남도 부여군청  041-830-2283
# 1    충청남도 부여군 부여읍 동남리 412    117    1  None  충청남도 부여군청  041-830-2283
# 2  충청남도 부여군 부여읍 동남리 152-1     59    1  None  충청남도 부여군청  041-830-2283
# 3  충청남도 부여군 부여읍 동남리 167-1    140    1  None  충청남도 부여군청  041-830-2283
# 4   충청남도 부여군 부여읍 군수리 22-1    110    1  None  충청남도 부여군청  041-830-2283
#
#           위도          경도     데이터기준일자   제공기관코드     제공기관명  전기차전용주차구획수       규모
# 0  36.284069  126.914531  2023-05-10  4570000  충청남도 부여군           5  100대 이하
# 1  36.279025  126.912881  2023-05-10  4570000  충청남도 부여군           6  200대 이하
# 2  36.271819  126.913187  2023-05-10  4570000  충청남도 부여군           3  100대 이하
# 3  36.270745  126.909562  2023-05-10  4570000  충청남도 부여군           7  200대 이하
# 4  36.267975  126.909502  2023-05-10  4570000  충청남도 부여군           6  200대 이하

# %% [markdown]
# 규모별 노외주차장 수, 노외 주차구획 수

# %%
df.규모.value_counts()
# Out:
# 20대 이하     3554
# 50대 이하     3422
# 100대 이하    1929
# 200대 이하    1208
# 400대 이하     468
# 400대 초과     179
# Name: 규모, dtype: int64

# %%
df.groupby("규모")["주차구획수"].sum()
# Out:
# 규모
# 20대 이하      43893
# 50대 이하     114370
# 100대 이하    137435
# 200대 이하    172223
# 400대 이하    125061
# 400대 초과    111546
# Name: 주차구획수, dtype: int64

# %%
df.groupby("규모")["전기차전용주차구획수"].sum()
# Out:
# 규모
# 20대 이하     3554
# 50대 이하     7675
# 100대 이하    7666
# 200대 이하    9186
# 400대 이하    6482
# 400대 초과    5654
# Name: 전기차전용주차구획수, dtype: int64

# %% [markdown]
# 부설주차장

# %%
def process(df, name):
    print(name)
    df2 = df.to_pandas()
    df2["규모"] = pd.cut(df2["총_주차대수"], bins=bins, labels=labels)
    print(df2.head())
    return df2


dfs2 = [
    process(df, name)
    for df, name in [
        (df_apt_complex_result, "apt_complex"),
        (df_apt_single_result, "apt_single"),
        (df_evbuilding_complex_result, "evbuilding_complex"),
        (df_evbuilding_single_result, "evbuilding_single"),
    ]
]
# Out:
# apt_complex
#     관리_상위_건축물대장_PK 시군구_코드  세대_수(세대)  옥내_기계식_대수(대)  옥외_기계식_대수(대)  옥내_자주식_대수(대)  \
# 0  11110-100180150  11110       710             0             0             0
# 1  11110-100182070  11110       810             0             0             0
# 2  11110-100183699  11110       416             0             0             0
# 3  11110-100185100  11110       288             0             0             0
# 4  11110-100185480  11110       112             0             0          6000
#
#    옥외_자주식_대수(대)    사용승인_일 시군구_코드_site 주_용도_코드  ... 옥내_기계식_대수(대)_site  \
# 0             0  20080711       11110   02000  ...                 0
# 1             0  20080725       11110   02000  ...                 0
# 2             0  20081121       11110   02000  ...                 0
# 3             0  20090320       11110   02000  ...                 0
# 4             0  20090408       11110   02000  ...                 0
#
#    옥외_기계식_대수(대)_site  옥내_자주식_대수(대)_site  옥외_자주식_대수(대)_site  사용승인_일_site  \
# 0                  0               1472                  8     20080711
# 1                  0               1003                102     20080215
# 2                  0                511                  3     20081122
# 3                  0                342                  0         None
# 4                  0                375                  0     20090408
#
#    옥내외_자주식_대수  총_주차대수 전기차_기축_대수  전기차_신축_최근10년_대수       규모
# 0        1480    1480        30                0  400대 초과
# 1        1105    1108        23                0  400대 초과
# 2         514     519        11                0  400대 초과
# 3         342     342         7                0  400대 이하
# 4         375     375         8                0  400대 이하
#
# [5 rows x 23 columns]
# apt_single
#                     관리_건축물대장_PK 시군구_코드 관리_상위_건축물대장_PK 시군구_코드_right 주_용도_코드  \
# 0  11110-1000000000000000166233  11110           None        11110   02000
# 1                   11110-10460  11110           None        11110   02000
# 2                   11110-13267  11110           None        11110   02000
# 3                   11110-14180  11110           None        11110   02000
# 4                   11110-15080  11110           None        11110   02000
#
#   주_용도_코드_명  세대_수(세대)  옥내_기계식_대수(대)  옥외_기계식_대수(대)  옥내_자주식_대수(대)  옥외_자주식_대수(대)  \
# 0      공동주택       181             0             0           257             0
# 1      공동주택       118             0             0           132            40
# 2      공동주택       365             0             0           204            24
# 3      공동주택       173             0             0           324             2
# 4      공동주택       136             0             0           138            25
#
#      사용승인_일  옥내외_자주식_대수  총_주차대수  전기차_기축_대수  전기차_신축_최근10년_대수       규모
# 0  20220929         257     257          6               13  400대 이하
# 1  20030808         172     172          4                0  200대 이하
# 2  20031129         228     228          5                0  400대 이하
# 3  20031119         326     326          7                0  400대 이하
# 4  19990130         163     163          4                0  200대 이하
# evbuilding_complex
#     관리_상위_건축물대장_PK 시군구_코드  세대_수(세대)  옥내_기계식_대수(대)  옥외_기계식_대수(대)  옥내_자주식_대수(대)  \
# 0       41590-3340  41590         0             0             0             0
# 1        30200-161  30200         0             0             0             0
# 2  48170-100261347  48170         0             0             0           110
# 3        11320-157  11320       217             0             0             0
# 4      41463-77464  41463         0             0             0             0
#
#    옥외_자주식_대수(대)    사용승인_일 시군구_코드_site 주_용도_코드  ... 옥내_기계식_대수(대)_site  \
# 0             0  20220822       41590   10000  ...                 0
# 1           588  20130705       30200   10000  ...                 0
# 2             0  20221227       48170   10000  ...                 0
# 3             0  20050916       11320   14000  ...                 0
# 4             0  19941006       41463   10000  ...                 0
#
#    옥외_기계식_대수(대)_site  옥내_자주식_대수(대)_site  옥외_자주식_대수(대)_site  사용승인_일_site  \
# 0                  0                  0                 95         None
# 1                  0                  0                328         None
# 2                  0                110                  0     20170605
# 3                  0                 95                 81     20050916
# 4                  0                  0                308         None
#
#    옥내외_자주식_대수  총_주차대수 전기차_기축_대수  전기차_신축_최근10년_대수       규모
# 0          95      95         2                5  100대 이하
# 1         328     328         7               17  400대 이하
# 2         110     110         3                6  200대 이하
# 3         176     176         4                0  200대 이하
# 4         308     308         7                0  400대 이하
#
# [5 rows x 23 columns]
# evbuilding_single
#        관리_건축물대장_PK 시군구_코드 관리_상위_건축물대장_PK 시군구_코드_right 주_용도_코드 주_용도_코드_명  \
# 0      43130-13811  43130           None        43130   14000      업무시설
# 1      41111-14685  41111           None        41111   10000    교육연구시설
# 2      11680-13453  11680           None        11680   14000      업무시설
# 3  26440-100237233  26440           None        26440   10000    교육연구시설
# 4  29200-100352886  29200           None        29200   14000      업무시설
#
#    세대_수(세대)  옥내_기계식_대수(대)  옥외_기계식_대수(대)  옥내_자주식_대수(대)  옥외_자주식_대수(대)    사용승인_일  \
# 0         0             0             0             0            66  19970825
# 1         0             0             0            53             0  20000721
# 2         0             0             0            63             6  19951121
# 3         0             0             0             0            61      None
# 4         0           152             0            82             0  20220114
#
#    옥내외_자주식_대수  총_주차대수  전기차_기축_대수  전기차_신축_최근10년_대수       규모
# 0          66      66          2                0  100대 이하
# 1          53      53          2                0  100대 이하
# 2          69      69          2                0  100대 이하
# 3          61      61          2                0  100대 이하
# 4          82     234          2                5  400대 이하

# %%
print([df2.규모.value_counts() for df2 in dfs2])
# Out:
# [400대 초과    9522
# 400대 이하    3548
# 200대 이하    1843
# 100대 이하     497
# 50대 이하        7
# 20대 이하        1
# Name: 규모, dtype: int64, 200대 이하    803
# 400대 이하    489
# 100대 이하    376
# 400대 초과    352
# 50대 이하       4
# 20대 이하       0
# Name: 규모, dtype: int64, 100대 이하    2930
# 200대 이하    1568
# 400대 초과    1086
# 400대 이하    1037
# 50대 이하      222
# 20대 이하       11
# Name: 규모, dtype: int64, 100대 이하    7532
# 200대 이하    4354
# 400대 이하    2885
# 400대 초과    2068
# 50대 이하      359
# 20대 이하        0
# Name: 규모, dtype: int64]

# %%
from functools import reduce

# print("주차장 수")
reduce(lambda x, y: x.add(y), [df2.규모.value_counts() for df2 in dfs2])
# Out:
# 20대 이하        12
# 50대 이하       592
# 100대 이하    11335
# 200대 이하     8568
# 400대 이하     7959
# 400대 초과    13028
# Name: 규모, dtype: int64

# %%
# print("총 주차대수")
reduce(lambda x, y: x.add(y), [df2.groupby("규모")["총_주차대수"].sum() for df2 in dfs2])
# Out:
# 규모
# 20대 이하          167
# 50대 이하        29216
# 100대 이하      801280
# 200대 이하     1235620
# 400대 이하     2279719
# 400대 초과    15911120
# Name: 총_주차대수, dtype: int64

# %%
# print("전기차 기축 대수")
reduce(lambda x, y: x.add(y), [df2.groupby("규모")["전기차_기축_대수"].sum() for df2 in dfs2])
# Out:
# 규모
# 20대 이하         38
# 50대 이하        665
# 100대 이하     22748
# 200대 이하     28418
# 400대 이하     49130
# 400대 초과    333924
# Name: 전기차_기축_대수, dtype: int64

# %%
# print("총 전기차_신축_최근10년_대수")
reduce(
    lambda x, y: x.add(y), [df2.groupby("규모")["전기차_신축_최근10년_대수"].sum() for df2 in dfs2]
)
# Out:
# 규모
# 20대 이하         29
# 50대 이하        708
# 100대 이하     20791
# 200대 이하     26539
# 400대 이하     41184
# 400대 초과    296522
# Name: 전기차_신축_최근10년_대수, dtype: int64

# %%
print("총 주차대수")
print(df2.groupby("규모")["총_주차대수"].sum())
print(df2.groupby("규모")[""].sum())
print("전기차 신축 10년 대수")
print(df2.groupby("규모")[""].sum())
